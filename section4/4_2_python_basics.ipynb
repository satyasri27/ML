# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# input statement

# %%
user_input = input("enter a value of x : ")
print("x = "+user_input)
# Out:
# x = 10

# %% [markdown]
# ***variables***

# %%
name = "alice"
age = 25
is_student = True
print(name)
print(age)
print(is_student)
# Out:
# alice
# 25
# True

# %% [markdown]
# ***DataTypes***
# - integers(int)
# - floating point(float)
# - string(str)
# - boolean - True False(bool)

# %%
x = "alice"
print(x)
print(type(x))
# Out:
# alice
# <class 'str'>

# %%
y = 10
print(y)
print(type(y))
# Out:
# 10
# <class 'int'>

# %%
a = True
b = False
print(a,b)
print(type(a))
# Out:
# True False
# <class 'bool'>
