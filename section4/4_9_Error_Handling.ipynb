# %% [markdown]
# 1.Simulate an error

# %%
num = int(input("enter a num" ))
print("you entered", num)
# Out:
# you entered 6

# %%
num = int(input("enter a num" ))
print("you entered", num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 num = int(input("enter a num" ))
#       2 print("you entered", num)
#
# ValueError: invalid literal for int() with base 10: 'sid'

# %% [markdown]
# 2.Using try and except block

# %%
try:
    num = int(input("enter a num" ))
    print("you entered", num)
except ValueError:
    print("that not a valid num")
# Out:
# that not a valid num

# %% [markdown]
# 3.Catching any errors

# %%
try:
    num = int(input("eneter a number: "))
    result = 10/num
    print("Result is:",result)
except:
    print("something went wrong")
# Out:
# something went wrong

# %%
try:
    num = int(input("eneter a number: "))
    result = 10/num
    print("Result is:",result)
except Exception as e:
    print("something went wrong: ",str(e))
# Out:
# something went wrong:  invalid literal for int() with base 10: 'sid'

# %%
try:
    num = int(input("eneter a number: "))
    result = 10/num
    print("Result is:",result)
except ValueError:
    print("please enter valid number")
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# please enter valid number

# %% [markdown]
# 5.Finally Block

# %%
try:
    num = int(input("enter a number: "))
    print("number is ",num)
except:
    print("somenthing went wrong")
finally:
    print("this is runs no matter what")
# Out:
# somenthing went wrong
# this is runs no matter what
