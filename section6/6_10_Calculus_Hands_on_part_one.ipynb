# %%
print("hello")
# Out:
# hello

# %%
import numpy as np
import matplotlib.pyplot as plt
np.set_printoptions(suppress=True)

# %% [markdown]
# 1. A simple line: y=2x+1

# %%
#define line function
def line_func(x):
    return 2*x+1

# %%
x = np.linspace(-3, 3, 100) #equally spaced 100values btw -3 to 3
y = line_func(x)

# %%
print(x[:5])
print(y[:5])
# Out:
# [-3.         -2.93939394 -2.87878788 -2.81818182 -2.75757576]
# [-5.         -4.87878788 -4.75757576 -4.63636364 -4.51515152]

# %% [markdown]
# slope = rise/run
#
#
# or
#
# slope = dy/dx
#
# or
#
# slope = change in y/ change in x

# %%
 #given x & y values, find teh slope of the line

plt.figure(figsize=(6,4))
plt.plot(x,y)
plt.title("line plot")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(alpha=0.3)
plt.show()

#choose two points on the line

x1, x2 = -2, 1
y1, y2 = line_func(x1), line_func(x2)

rise = y2-y1
run = x2-x1

slope = rise/run
print("-"*50)
print("line example")
print("point 1:",f"({x1},{y1})")
print("point 2:",f"({x2},{y2})")
print("Rise:",rise)
print("Run:",run)
print("slope", slope)
print("-"*50)
# Out:
# --------------------------------------------------
# line example
# point 1: (-2,-3)
# point 2: (1,3)
# Rise: 6
# Run: 3
# slope 2.0
# --------------------------------------------------

# %%
x1, x2 = -2, 1
y1, y2 = line_func(x1), line_func(x2)
print(y1, y2)
# Out:
# -3 3
