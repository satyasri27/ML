# %%
# %pip install SQLAlchmey psycopq2-binary pandas openpyxl pyarrow -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement SQLAlchmey (from versions: none)
# ERROR: No matching distribution found for SQLAlchmey
#
# [notice] A new release of pip available: 22.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sqlalchemy
print(sqlalchemy.__version__)
# Out:
# 2.0.50

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
import sys
print(sys.version)
# Out:
# 3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)]

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\satya\OneDrive\Desktop\udemyml\Section_7\7_6_assessment

# %%
import os

print(os.listdir())
# Out:
# ['7_6_assignment.ipynb', 'insurance.csv', 'insurance_from_db.xlsx', 'test.parquet']

# %%
CSV_FILE = "insurance.csv"
df_csv = pd.read_csv(CSV_FILE)

# %%
df_csv.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df_csv.shape
# Out:
# (1338, 7)

# %%
#connect to the database
#format => "postgresql://[your_user_name]:[test_password]@[host]:5432/[database_name]"
connection_string = "postgresql://postgres:satya%402005@localhost:5432/ml_db"

engine = create_engine(connection_string)

# %%
with engine.connect() as con:
    print("connected sucessfully")
# Out:
# connected sucessfully

# %%
query = "SELECT * FROM datasets.insurance"
df_db = pd.read_sql(query, con=engine)

# %%
df_db.head()
# Out:
#    age     sex     bmi  children smoker     region     charges
# 0   19  female  27.900         0    yes  southwest  16884.9240
# 1   18    male  33.770         1     no  southeast   1725.5522
# 2   28    male  33.000         3     no  southeast   4449.4620
# 3   33    male  22.705         0     no  northwest  21984.4700
# 4   32    male  28.880         0     no  northwest   3866.8552

# %%
print(df_csv.shape)
print(df_db.shape)
# Out:
# (1338, 7)
# (1338, 7)

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
print(os.path.exists("insurance_from_db.xlsx"))
# Out:
# True

# %%
df_db.to_excel(
    "insurance_from_db.xlsx",
    index=False
)

# %%
print(df_db.columns.tolist())
print(df_db.columns.duplicated().any())
# Out:
# ['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges']
# False

# %%
print(df_db.dtypes)
# Out:
# age           int64
# sex             str
# bmi         float64
# children      int64
# smoker          str
# region          str
# charges     float64
# dtype: object

# %%
# %pip install pyarrow==17.0.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip show pyarrow
# Out:
# Name: pyarrow
# Version: 17.0.0
# Summary: Python library for Apache Arrow
# Home-page:
# Author:
# Author-email:
# License: Apache Software License
# Location: c:\Users\satya\OneDrive\Desktop\udemyml\Section_7\.venv311\Lib\site-packages
# Requires: numpy
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
df_db.to_parquet(
    "insurance_from_db.parquet",
    index=False
)

# %%
import os

print(os.path.exists("insurance_from_db.xlsx"))
print(os.path.exists("insurance_from_db.parquet"))
# Out:
# True
# True

# %%
import os

for f in [
    "insurance_from_db.xlsx",
    "insurance_from_db.parquet"
]:
    size_kb = os.path.getsize(f) / 1024
    print(f"{f}: {size_kb:.2f} KB")
# Out:
# insurance_from_db.xlsx: 53.13 KB
# insurance_from_db.parquet: 22.51 KB

# %%
print(df_csv.shape)
print(df_db.shape)
# Out:
# (1338, 7)
# (1338, 7)
